# %%
print ("Seja Bem Vindo a Calculadora Python")
num1 = int(input ("Digite seu primeiro numero:"))
# Out:
# Seja Bem Vindo a Calculadora Python
# Digite seu primeiro numero:1

# %%
num2 = int(input ("Digite seu segundo numero:"))
# Out:
# Digite seu segundo numero:1

# %%
Operadores = {'soma': num1 + num2, 'subtração': num1 - num2}

# %%
Lista_op = ["+","-","*","/"]

# %%
Lista_op[1]
# Out:
# '-'

# %%
print(Operadores)
# Out:
# {'soma': 2, 'subtração': 0}

# %%
print("Qual operação matematica você deseja fazer?\n Digite 1 para soma\n Digite 2 para subtração\n Digite 3 para divisão\n Digite 4 para mutiplicação")
op = int(input())
# Out:
# Qual operação matematica você deseja fazer?
#  Digite 1 para soma
#  Digite 2 para subtração
#  Digite 3 para divisão
#  Digite 4 para mutiplicação
# 1

# %%
if op == 1:
    print("O total é: ",num1 + num2)
elif op == 2:
    print("O total é: ",num1 - num2)
elif op == 3:
      print("O total é: ",num1 / num2)
elif op == 4:
      print("O total é: ",num1 * num2)
else:
      print("Operador invalido")
# Out:
# O total é:  2

# %%
print(Lista_op[op])
# Out:
# -

# %%
valor = num1, Lista_op[op], num2

# %%
print(valor)
# Out:
# (1, '-', 1)
